# %%
from PIL import Image

# %%
import numpy as np

# %%
pil = Image.open(r"C:\Users\Aaditree Jaisswal\Desktop\thor.jpg")

# %%
pil
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=220x246 at 0x219A842E108>

# %%
arr  = np.array(pil)

# %%
arr
# Out:
# array([[[ 67,  68,  60],
#         [ 67,  68,  60],
#         [ 68,  69,  61],
#         ...,
#         [ 79,  86,  70],
#         [ 77,  83,  69],
#         [ 75,  81,  67]],
#
#        [[ 66,  67,  59],
#         [ 67,  68,  60],
#         [ 67,  68,  60],
#         ...,
#         [ 81,  88,  72],
#         [ 79,  85,  71],
#         [ 78,  84,  70]],
#
#        [[ 66,  67,  59],
#         [ 66,  67,  59],
#         [ 67,  68,  60],
#         ...,
#         [ 82,  89,  73],
#         [ 81,  87,  73],
#         [ 80,  86,  72]],
#
#        ...,
#
#        [[139, 141, 119],
#         [144, 146, 122],
#         [138, 138, 112],
#         ...,
#         [ 54,  10,  11],
#         [ 52,  10,  11],
#         [ 51,   9,  10]],
#
#        [[129, 131, 110],
#         [137, 139, 117],
#         [119, 119,  95],
#         ...,
#         [ 55,  11,  12],
#         [ 54,  10,  11],
#         [ 53,   9,  10]],
#
#        [[108, 110,  89],
#         [124, 126, 104],
#         [107, 106,  85],
# ...

# %%
arr.shape
# Out:
# (246, 220, 3)

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(arr)

# %%
red = arr[:,:,0]

# %%
plt.imshow(red)

# %%
blue = arr[:,:,1]

# %%
plt.imshow(blue)

# %%
green = arr[:,:,1]

# %%
plt.imshow(green)

# %%
w =arr.copy()

# %%
w
# Out:
# array([[[ 67,  68,  60],
#         [ 67,  68,  60],
#         [ 68,  69,  61],
#         ...,
#         [ 79,  86,  70],
#         [ 77,  83,  69],
#         [ 75,  81,  67]],
#
#        [[ 66,  67,  59],
#         [ 67,  68,  60],
#         [ 67,  68,  60],
#         ...,
#         [ 81,  88,  72],
#         [ 79,  85,  71],
#         [ 78,  84,  70]],
#
#        [[ 66,  67,  59],
#         [ 66,  67,  59],
#         [ 67,  68,  60],
#         ...,
#         [ 82,  89,  73],
#         [ 81,  87,  73],
#         [ 80,  86,  72]],
#
#        ...,
#
#        [[139, 141, 119],
#         [144, 146, 122],
#         [138, 138, 112],
#         ...,
#         [ 54,  10,  11],
#         [ 52,  10,  11],
#         [ 51,   9,  10]],
#
#        [[129, 131, 110],
#         [137, 139, 117],
#         [119, 119,  95],
#         ...,
#         [ 55,  11,  12],
#         [ 54,  10,  11],
#         [ 53,   9,  10]],
#
#        [[108, 110,  89],
#         [124, 126, 104],
#         [107, 106,  85],
# ...

# %%
plt.imshow(w)

# %%
w[:,:,[1,2]]
# Out:
# array([[[ 68,  60],
#         [ 68,  60],
#         [ 69,  61],
#         ...,
#         [ 86,  70],
#         [ 83,  69],
#         [ 81,  67]],
#
#        [[ 67,  59],
#         [ 68,  60],
#         [ 68,  60],
#         ...,
#         [ 88,  72],
#         [ 85,  71],
#         [ 84,  70]],
#
#        [[ 67,  59],
#         [ 67,  59],
#         [ 68,  60],
#         ...,
#         [ 89,  73],
#         [ 87,  73],
#         [ 86,  72]],
#
#        ...,
#
#        [[141, 119],
#         [146, 122],
#         [138, 112],
#         ...,
#         [ 10,  11],
#         [ 10,  11],
#         [  9,  10]],
#
#        [[131, 110],
#         [139, 117],
#         [119,  95],
#         ...,
#         [ 11,  12],
#         [ 10,  11],
#         [  9,  10]],
#
#        [[110,  89],
#         [126, 104],
#         [106,  85],
#         ...,
#         [ 11,  12],
#         [ 10,  11],
#         [  9,  10]]], dtype=uint8)

# %%
w[:,:,[1,2] ]= 0

# %%
w
# Out:
# array([[[ 67,   0,   0],
#         [ 67,   0,   0],
#         [ 68,   0,   0],
#         ...,
#         [ 79,   0,   0],
#         [ 77,   0,   0],
#         [ 75,   0,   0]],
#
#        [[ 66,   0,   0],
#         [ 67,   0,   0],
#         [ 67,   0,   0],
#         ...,
#         [ 81,   0,   0],
#         [ 79,   0,   0],
#         [ 78,   0,   0]],
#
#        [[ 66,   0,   0],
#         [ 66,   0,   0],
#         [ 67,   0,   0],
#         ...,
#         [ 82,   0,   0],
#         [ 81,   0,   0],
#         [ 80,   0,   0]],
#
#        ...,
#
#        [[139,   0,   0],
#         [144,   0,   0],
#         [138,   0,   0],
#         ...,
#         [ 54,   0,   0],
#         [ 52,   0,   0],
#         [ 51,   0,   0]],
#
#        [[129,   0,   0],
#         [137,   0,   0],
#         [119,   0,   0],
#         ...,
#         [ 55,   0,   0],
#         [ 54,   0,   0],
#         [ 53,   0,   0]],
#
#        [[108,   0,   0],
#         [124,   0,   0],
#         [107,   0,   0],
# ...

# %%
plt.imshow(w)

# %%
g = arr.mean(axis=0) #across row

# %%
plt.imshow(g,cmap = "gray")

# %%
g = arr.mean(axis=1) #across column

# %%
plt.imshow(g,cmap = "gray")

# %%
g = arr.mean(axis=2) #across depth

# %%
plt.imshow(g,cmap ="gray")
